# %% [markdown]
# ![alt text](img/LM.png)
# # Kurs: Deep Learning, Text Mining i XAI w Pythonie
#
# ## Autor: Piotr Ćwiakowski
#
# ### Lekcja 9. Sieci konwolucyjne (CNN)

# %% [markdown]
# Aktualnie (w kwietniu 2023 r.) jest konflikt pomiędzy najnowszymi wersjami pakietów matplotlib i keras instalowanymi przez conda/pip, stąd w głównych plikach nie wykonujemy w jednej sesji komend graficznych. Zamiast tego wizualizacja zbiorów następuje w poniższym pliku.

# %% [markdown]
# # 1 Mnist

# %%
# Ogólne pakiety
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sieci neuronowe
from keras.datasets import mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train.shape, x_test.shape, y_train.shape, y_test.shape

# Policzmy liczbę kategorii
num_labels = len(np.unique(y_train))

# Zmienna objaśniana musi być w formacie one-hot-encoding
y_train.shape, y_test.shape

# Normalizacja
x_train = x_train/255
x_test = x_test/255

# %%
fig, ax = plt.subplots(2, 7, figsize=(15, 5))
ax = ax.flatten()

for i in range(14):  
    ax[i].imshow(x_train[i], cmap=plt.get_cmap('gray'))

# %% [markdown]
# # 2 Szeregi czasowe

# %%
# dane wczytujemy z użyciem numpy, od razu dzieląc na zbiór x iy
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

x_train, y_train = readucr("data/FordA_TRAIN.tsv")
x_test, y_test = readucr("data/FordA_TEST.tsv")

# konwersja klasy -1 na 0
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
# Narysowanie szeregów
plt.figure()
for c in [0, 1]:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
